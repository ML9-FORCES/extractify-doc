# %% [markdown]
# # **Model-Wrapper**

# %%
#External libs
# !pip install transformers
# !pip install tensorflow-cpu
# !pip install numpy
# !pip install gdown==4.1.1

# %%
#Library
from transformers import BertTokenizer
import tensorflow as tf
import numpy as np
import json
import gdown
import os

# %%
#bert_classifier Class
class bert_classifier:
    def __init__(self):
        path='./static/MODELS/bert_classifier'
        url='https://drive.google.com/drive/folders/1u8pPnb2qPTt67Yf3v8enC2pF2HpyWaEc'
        if not os.path.isdir(path):
            gdown.download_folder(url,output=path, quiet=False)
        self.tokenizer = BertTokenizer.from_pretrained('bert-base-cased')
        self.model = tf.keras.models.load_model(path) 

    def preprocessing(self, input_data):
        tokens = self.tokenizer.encode_plus(input_data, max_length=50,
                                   truncation=True, padding='max_length',
                                   add_special_tokens=True, return_token_type_ids=False,
                                   return_tensors='tf')
        # tokenizer returns int32 tensors, we need to return float64, so we use tf.cast
        in_tensor = {'input_ids': tf.cast(tokens['input_ids'], tf.float64),
            'attention_mask': tf.cast(tokens['attention_mask'], tf.float64)}
        return in_tensor 

    def predict(self, input_data):
        return self.model.predict(input_data)[0]

    def postprocessing(self, input_data):
        bins={1:'key',2:'value',0:'other'}
        return bins[np.argmax(input_data)],str(np.max(input_data))

    def compute_prediction(self, input_data):
        try:
            input_data = self.preprocessing(input_data)
            prediction = self.predict(input_data)
            prediction = self.postprocessing(prediction)
        except Exception as e:
            return {"status": "Error", "message": str(e)}
        return prediction

#linking Classifier Class
class linking_classifier:
  def __init__(self):
    path='./static/MODELS/linking'
    url='https://drive.google.com/drive/folders/1vDUBSS6cXyZdQTwtcXhg8BXBGGR_s7FT'
    if not os.path.isdir(path):
      gdown.download_folder(url,output=path, quiet=False)
    self.model = tf.keras.models.load_model(path)  
 
  def ext(self,box):
    width=box[2]-box[0]
    height=box[3]-box[1]
    c_x=(box[0]+box[2])/2
    c_y=(box[1]+box[3])/2
    return c_x,c_y,width,height

  def preprocessing(self, input_data1,input_data2):
    b1=self.ext(input_data1)
    b2=self.ext(input_data2)
    dis=(b1[0]-b2[0])**2 + (b1[1]-b2[1])**2
    dis=dis**0.5
    sin=(b1[1]-b2[1])/dis
    sin*= -1 if sin<0 else 1
    relative_width = b1[2]/b2[2] if b2[2]>b1[2] else b2[2]/b1[2]
    relative_height = b1[3]/b2[3] if b2[3]>b1[3] else b2[3]/b1[3]
    return [dis/1000,sin,relative_width,relative_height]

  def predict(self, input_data):
    return self.model.predict(np.array([input_data]))[0]

  def postprocessing(self, input_data):
    bins={1:'linked',0:'unlinked'}
    return bins[np.argmax(input_data)],str(np.max(input_data))

  def compute_prediction(self, input_data1,input_data2):
    try:
      input_data = self.preprocessing(input_data1,input_data2)
      prediction = self.predict(input_data)
      prediction = self.postprocessing(prediction)
    except Exception as e:
      return {"status": "Error", "message": str(e)}
    return prediction

#Wrapper Class
class Wrapper:
  def __init__(self,classifier,linker):
    self.data = None
    self.classifier = classifier
    self.linker=linker
    self.keys=[]
    self.values=[]

  def preprocessing(self,json):
    self.data=json
    try:
      for i in self.data:
        del i['label']
        del i ['linking']
    except:
      pass

  def classification(self):
    for i in self.data['form']:
      i['linking']=[]
      i['label']=list(self.classifier.compute_prediction(i['text']))
      if i['label'][0]=='key':
        self.keys.append(i['id'])
      if i['label'][0]=='value':
        self.values.append(i['id'])

  def linking(self):
    for i in self.keys:
      for j in self.values:
        link = list(self.linker.compute_prediction(self.data['form'][i]['box'],self.data['form'][j]['box']))
        if link[0] == 'linked':
          self.data['form'][i]['linking'].append([i,j,link[1]])
          self.data['form'][j]['linking'].append([i,j,link[1]])

  def generate(self,json):
    self.preprocessing(json)
    self.classification()
    self.linking()
    return self.data

# %%
#initiating Models
classifier = bert_classifier()
linker = linking_classifier() 

#initiating Wrapper
wrapper = Wrapper(classifier,linker)

# %% [markdown]
# **`wrapper.generate(Input_json) ==> Output_json`**

# %%
#Download Dataset For Testing
# !git clone https://github.com/ML9-FORCES/extractify-doc
# Out:
# Cloning into 'extractify-doc'...
# remote: Enumerating objects: 422, done.
# remote: Counting objects: 100% (422/422), done.
# remote: Compressing objects: 100% (221/221), done.
# remote: Total 422 (delta 202), reused 417 (delta 200), pack-reused 0
# Receiving objects: 100% (422/422), 16.02 MiB | 32.93 MiB/s, done.
# Resolving deltas: 100% (202/202), done.

# %%
#Testing on a JSON file
path='/content/extractify-doc/dataset/testing_data/annotations/82092117.json'

input_json=json.load(open(path,'r'))     #Input OCR data
output_json=wrapper.generate(input_json) #Output data with Classification & linking

print(json.dumps(output_json,indent=4))
# Out:
# {
#     "form": [
#         {
#             "box": [
#                 61,
#                 127,
#                 143,
#                 211
#             ],
#             "text": "",
#             "label": [
#                 "other",
#                 "0.5835624"
#             ],
#             "words": [
#                 {
#                     "box": [
#                         61,
#                         127,
#                         143,
#                         211
#                     ],
#                     "text": ""
#                 }
#             ],
#             "linking": [],
#             "id": 0
#         },
#         {
#             "box": [
#                 102,
#                 345,
#                 129,
#                 359
#             ],
#             "text": "TO:",
#             "label": [
#                 "key",
#                 "0.97279173"
#             ],
#             "words": [
#                 {
#                     "box": [
#                         102,
#                         345,
#                         129,
#                         359
#                     ],
#                     "text": "TO:"
#                 }
#             ],
#             "linking": [
#                 [
#                     1,
#                     14,
#                     "0.95006293"
#                 ],
#                 [
#                     1,
#                     14,
#                     "0.95006293"
#                 ],
#                 [
#                     1,
#                     14,
#                     "0.95006293"
#                 ],
#                 [
#                     1,
#                     14,
#                     "0.95006293"
#                 ]
#             ],
#             "id": 1
#         },
#         {
#             "box": [
#                 102,
#                 406,
#                 147,
#                 423
#             ],
#             "text": "DATE:",
#             "label": [
#                 "key",
#                 "0.9807748"
#             ],
#             "words": [
#                 {
#                     "box": [
#                         102,
#                         406,
#                         147,
#                         423
#                     ],
#                     "text": "DATE:"
#                 }
#             ],
#             "linking": [
#                 [
#                     2,
#                     27,
#                     "0.9670255"
#                 ],
#                 [
#                     2,
#                     27,
#                     "0.9670255"
#                 ],
#                 [
#                     2,
#                     27,
#                     "0.9670255"
#                 ],
#                 [
#                     2,
#                     27,
#                     "0.9670255"
#                 ]
#             ],
#             "id": 2
#         },
#         {
#             "box": [
#                 461,
#                 440,
#                 475,
#                 455
#             ],
#             "text": "3",
#             "label": [
#                 "value",
#                 "0.62867475"
#             ],
#             "words": [
#                 {
#                     "box": [
#                         461,
#                         440,
#                         475,
#                         455
#                     ],
#                     "text": "3"
#                 }
#             ],
#             "linking": [
#                 [
#                     19,
#                     3,
#                     "0.87029165"
#                 ],
#                 [
#                     19,
#                     3,
#                     "0.87029165"
#                 ],
#                 [
#                     19,
#                     3,
#                     "0.87029165"
#                 ],
#                 [
#                     19,
#                     3,
#                     "0.87029165"
#                 ]
#             ],
#             "id": 3
#         },
#         {
#             "box": [
#                 249,
#                 84,
#                 274,
#                 98
#             ],
#             "text": "Fax:",
#             "label": [
#                 "key",
#                 "0.8984803"
#             ],
#             "words": [
#                 {
#                     "box": [
#                         249,
#                         84,
#                         274,
#                         98
#                     ],
#                     "text": "Fax:"
#                 }
#             ],
#             "linking": [
#                 [
#                     4,
#                     7,
#                     "0.9636014"
#                 ],
#                 [
#                     4,
#                     7,
#                     "0.9636014"
#                 ],
#                 [
#                     4,
#                     7,
#                     "0.9636014"
#                 ],
#                 [
#                     4,
#                     7,
#                     "0.9636014"
#                 ]
#             ],
#             "id": 4
#         },
#         {
#             "box": [
#                 103,
#                 691,
#                 139,
#                 708
#             ],
#             "text": "NOTE:",
#             "label": [
#                 "key",
#                 "0.8093358"
#             ],
#             "words": [
#                 {
#                     "box": [
#                         103,
#                         691,
#                         139,
#                         708
#                     ],
#                     "text": "NOTE:"
#                 }
#             ],
#             "linking": [],
#             "id": 5
#         },
#         {
#             "box": [
#                 633,
#                 775,
#                 653,
#                 874
#             ],
#             "text": "82092117",
#             "label": [
#                 "other",
#                 "0.9845036"
#             ],
#             "words": [
#                 {
#                     "box": [
#                         633,
#                         775,
#                         653,
#                         874
#                     ],
#                     "text": "82092117"
#                 }
#             ],
#             "linking": [],
#             "id": 6
#         },
#         {
#             "text": "614 -466 -5087",
#             "box": [
#                 275,
#                 82,
#                 354,
#                 101
#             ],
#             "linking": [
#                 [
#                     4,
#                     7,
#                     "0.9636014"
#                 ],
#                 [
#                     4,
#                     7,
#                     "0.9636014"
#                 ],
#                 [
#                     9,
#                     7,
#                     "0.93015456"
#                 ],
#                 [
#                     9,
#                     7,
#                     "0.93015456"
#                 ],
#                 [
#                     4,
#                     7,
#                     "0.9636014"
#                 ],
#                 [
#                     4,
#                     7,
#                     "0.9636014"
#                 ],
#                 [
#                     9,
#                     7,
#                     "0.93015456"
#                 ],
#                 [
#                     9,
#                     7,
#                     "0.93015456"
#                 ]
#             ],
#             "label": [
#                 "value",
#                 "0.9356099"
#             ],
#             "words": [
#                 {
#                     "text": "614",
#                     "box": [
#                         275,
#                         85,
#                         295,
#                         99
#                     ]
#                 },
#                 {
#                     "text": "-466",
#                     "box": [
#                         296,
#                         84,
#                         320,
#                         101
#                     ]
#                 },
#                 {
#                     "text": "-5087",
#                     "box": [
#                         320,
#                         82,
#                         354,
#                         100
#                     ]
#                 }
#             ],
#             "id": 7
#         },
#         {
#             "text": "Dec 10 '98 17 :46 P. 01",
#             "box": [
#                 419,
#                 82,
#                 589,
#                 101
#             ],
#             "linking": [],
#             "label": [
#                 "other",
#                 "0.67661065"
#             ],
#             "words": [
#                 {
#                     "text": "Dec",
#                     "box": [
#                         419,
#                         84,
#                         439,
#                         98
#                     ]
#                 },
#                 {
#                     "text": "10",
#                     "box": [
#                         444,
#                         85,
#                         459,
#                         99
#                     ]
#                 },
#                 {
#                     "text": "'98",
#                     "box": [
#                         464,
#                         84,
#                         484,
#                         98
#                     ]
#                 },
#                 {
#                     "text": "17",
#                     "box": [
#                         499,
#                         85,
#                         516,
#                         98
#                     ]
#                 },
#                 {
#                     "text": ":46",
#                     "box": [
#                         515,
#                         84,
#                         535,
#                         101
#                     ]
#                 },
#                 {
#                     "text": "P.",
#                     "box": [
#                         554,
#                         82,
#                         574,
#                         97
#                     ]
#                 },
#                 {
#                     "text": "01",
#                     "box": [
#                         574,
#                         84,
#                         589,
#                         99
#                     ]
#                 }
#             ],
#             "id": 8
#         },
#         {
#             "text": "ATT. GEN. ADMIN. OFFICE",
#             "box": [
#                 103,
#                 84,
#                 246,
#                 100
#             ],
#             "linking": [
#                 [
#                     9,
#                     7,
#                     "0.93015456"
#                 ],
#                 [
#                     9,
#                     7,
#                     "0.93015456"
#                 ],
#                 [
#                     9,
#                     7,
#                     "0.93015456"
#                 ],
#                 [
#                     9,
#                     7,
#                     "0.93015456"
#                 ]
#             ],
#             "label": [
#                 "key",
#                 "0.5672311"
#             ],
#             "words": [
#                 {
#                     "text": "ATT.",
#                     "box": [
#                         103,
#                         85,
#                         127,
#                         100
#                     ]
#                 },
#                 {
#                     "text": "GEN.",
#                     "box": [
#                         133,
#                         85,
#                         160,
#                         99
#                     ]
#                 },
#                 {
#                     "text": "ADMIN.",
#                     "box": [
#                         166,
#                         84,
#                         204,
#                         99
#                     ]
#                 },
#                 {
#                     "text": "OFFICE",
#                     "box": [
#                         207,
#                         84,
#                         246,
#                         98
#                     ]
#                 }
#             ],
#             "id": 9
#         },
#         {
#             "text": "Attorney General Betty D. Montgomery",
#             "box": [
#                 147,
#                 148,
#                 305,
#                 191
#             ],
#             "linking": [],
#             "label": [
#                 "value",
#                 "0.9451362"
#             ],
#             "words": [
#                 {
#                     "text": "Attorney",
#                     "box": [
#                         147,
#                         148,
#                         213,
#                         168
#                     ]
#                 },
#                 {
#                     "text": "General",
#                     "box": [
#                         216,
#                         151,
#                         275,
#                         168
#                     ]
#                 },
#                 {
#                     "text": "Betty",
#                     "box": [
#                         148,
#                         172,
#                         187,
#                         190
#                     ]
#                 },
#                 {
#                     "text": "D.",
#                     "box": [
#                         191,
#                         169,
#                         206,
#                         187
#                     ]
#                 },
#                 {
#                     "text": "Montgomery",
#                     "box": [
#                         211,
#                         170,
#                         305,
#                         191
#                     ]
#                 }
#             ],
#             "id": 10
#         },
#         {
#             "text": "CONFIDENTIAL FACSIMILE TRANSMISSION COVER SHEET",
#             "box": [
#                 264,
#                 249,
#                 467,
#                 281
#             ],
#             "linking": [],
#             "label": [
#                 "other",
#                 "0.90039223"
#             ],
#             "words": [
#                 {
#                     "text": "CONFIDENTIAL",
#                     "box": [
#                         275,
#                         249,
#                         377,
#                         267
#                     ]
#                 },
#                 {
#                     "text": "FACSIMILE",
#                     "box": [
#                         380,
#                         250,
#                         457,
#                         267
#                     ]
#                 },
#                 {
#                     "text": "TRANSMISSION",
#                     "box": [
#                         264,
#                         267,
#                         369,
#                         281
#                     ]
#                 },
#                 {
#                     "text": "COVER",
#                     "box": [
#                         369,
#                         267,
#                         422,
#                         281
#                     ]
#                 },
#                 {
#                     "text": "SHEET",
#                     "box": [
#                         420,
#                         267,
#                         467,
#                         281
#                     ]
#                 }
#             ],
#             "id": 11
#         },
#         {
#             "text": "(614) 466- 5087",
#             "box": [
#                 352,
#                 296,
#                 438,
#                 314
#             ],
#             "linking": [
#                 [
#                     13,
#                     12,
#                     "0.96013594"
#                 ],
#                 [
#                     13,
#                     12,
#                     "0.96013594"
#                 ],
#                 [
#                     13,
#                     12,
#                     "0.96013594"
#                 ],
#                 [
#                     13,
#                     12,
#                     "0.96013594"
#                 ]
#             ],
#             "label": [
#                 "value",
#                 "0.9335249"
#             ],
#             "words": [
#                 {
#                     "text": "(614)",
#                     "box": [
#                         352,
#                         297,
#                         383,
#                         314
#                     ]
#                 },
#                 {
#                     "text": "466-",
#                     "box": [
#                         384,
#                         296,
#                         405,
#                         313
#                     ]
#                 },
#                 {
#                     "text": "5087",
#                     "box": [
#                         406,
#                         297,
#                         438,
#                         312
#                     ]
#                 }
#             ],
#             "id": 12
#         },
#         {
#             "text": "FAX NO.",
#             "box": [
#                 289,
#                 296,
#                 351,
#                 311
#             ],
#             "linking": [
#                 [
#                     13,
#                     12,
#                     "0.96013594"
#                 ],
#                 [
#                     13,
#                     12,
#                     "0.96013594"
#                 ],
#                 [
#                     13,
#                     12,
#                     "0.96013594"
#                 ],
#                 [
#                     13,
#                     12,
#                     "0.96013594"
#                 ]
#             ],
#             "label": [
#                 "key",
#                 "0.9848793"
#             ],
#             "words": [
#                 {
#                     "text": "FAX",
#                     "box": [
#                         289,
#                         297,
#                         323,
#                         311
#                     ]
#                 },
#                 {
#                     "text": "NO.",
#                     "box": [
#                         324,
#                         296,
#                         351,
#                         311
#                     ]
#                 }
#             ],
#             "id": 13
#         },
#         {
#             "text": "George Baroody",
#             "box": [
#                 142,
#                 342,
#                 236,
#                 360
#             ],
#             "linking": [
#                 [
#                     1,
#                     14,
#                     "0.95006293"
#                 ],
#                 [
#                     1,
#                     14,
#                     "0.95006293"
#                 ],
#                 [
#                     1,
#                     14,
#                     "0.95006293"
#                 ],
#                 [
#                     1,
#                     14,
#                     "0.95006293"
#                 ]
#             ],
#             "label": [
#                 "value",
#                 "0.9436081"
#             ],
#             "words": [
#                 {
#                     "text": "George",
#                     "box": [
#                         142,
#                         345,
#                         185,
#                         359
#                     ]
#                 },
#                 {
#                     "text": "Baroody",
#                     "box": [
#                         187,
#                         342,
#                         236,
#                         360
#                     ]
#                 }
#             ],
#             "id": 14
#         },
#         {
#             "text": "(336) 335- 7392",
#             "box": [
#                 223,
#                 376,
#                 312,
#                 393
#             ],
#             "linking": [
#                 [
#                     16,
#                     15,
#                     "0.9394853"
#                 ],
#                 [
#                     16,
#                     15,
#                     "0.9394853"
#                 ],
#                 [
#                     17,
#                     15,
#                     "0.9026804"
#                 ],
#                 [
#                     17,
#                     15,
#                     "0.9026804"
#                 ],
#                 [
#                     16,
#                     15,
#                     "0.9394853"
#                 ],
#                 [
#                     16,
#                     15,
#                     "0.9394853"
#                 ],
#                 [
#                     17,
#                     15,
#                     "0.9026804"
#                 ],
#                 [
#                     17,
#                     15,
#                     "0.9026804"
#                 ]
#             ],
#             "label": [
#                 "value",
#                 "0.93987066"
#             ],
#             "words": [
#                 {
#                     "text": "(336)",
#                     "box": [
#                         223,
#                         376,
#                         254,
#                         393
#                     ]
#                 },
#                 {
#                     "text": "335-",
#                     "box": [
#                         257,
#                         376,
#                         284,
#                         390
#                     ]
#                 },
#                 {
#                     "text": "7392",
#                     "box": [
#                         284,
#                         376,
#                         312,
#                         391
#                     ]
#                 }
#             ],
#             "id": 15
#         },
#         {
#             "text": "FAX NUMBER:",
#             "box": [
#                 102,
#                 374,
#                 200,
#                 391
#             ],
#             "linking": [
#                 [
#                     16,
#                     15,
#                     "0.9394853"
#                 ],
#                 [
#                     16,
#                     18,
#                     "0.5065808"
#                 ],
#                 [
#                     16,
#                     15,
#                     "0.9394853"
#                 ],
#                 [
#                     16,
#                     18,
#                     "0.5065808"
#                 ],
#                 [
#                     16,
#                     15,
#                     "0.9394853"
#                 ],
#                 [
#                     16,
#                     18,
#                     "0.5065808"
#                 ],
#                 [
#                     16,
#                     15,
#                     "0.9394853"
#                 ],
#                 [
#                     16,
#                     18,
#                     "0.5065808"
#                 ]
#             ],
#             "label": [
#                 "key",
#                 "0.96717805"
#             ],
#             "words": [
#                 {
#                     "text": "FAX",
#                     "box": [
#                         102,
#                         374,
#                         131,
#                         391
#                     ]
#                 },
#                 {
#                     "text": "NUMBER:",
#                     "box": [
#                         134,
#                         374,
#                         200,
#                         391
#                     ]
#                 }
#             ],
#             "id": 16
#         },
#         {
#             "text": "PHONE NUMBER:",
#             "box": [
#                 383,
#                 376,
#                 500,
#                 391
#             ],
#             "linking": [
#                 [
#                     17,
#                     15,
#                     "0.9026804"
#                 ],
#                 [
#                     17,
#                     18,
#                     "0.949155"
#                 ],
#                 [
#                     17,
#                     15,
#                     "0.9026804"
#                 ],
#                 [
#                     17,
#                     18,
#                     "0.949155"
#                 ],
#                 [
#                     17,
#                     15,
#                     "0.9026804"
#                 ],
#                 [
#                     17,
#                     18,
#                     "0.949155"
#                 ],
#                 [
#                     17,
#                     15,
#                     "0.9026804"
#                 ],
#                 [
#                     17,
#                     18,
#                     "0.949155"
#                 ]
#             ],
#             "label": [
#                 "key",
#                 "0.97728026"
#             ],
#             "words": [
#                 {
#                     "text": "PHONE",
#                     "box": [
#                         383,
#                         376,
#                         433,
#                         391
#                     ]
#                 },
#                 {
#                     "text": "NUMBER:",
#                     "box": [
#                         436,
#                         377,
#                         500,
#                         391
#                     ]
#                 }
#             ],
#             "id": 17
#         },
#         {
#             "text": "(336) 335- 7363",
#             "box": [
#                 504,
#                 376,
#                 592,
#                 393
#             ],
#             "linking": [
#                 [
#                     16,
#                     18,
#                     "0.5065808"
#                 ],
#                 [
#                     16,
#                     18,
#                     "0.5065808"
#                 ],
#                 [
#                     17,
#                     18,
#                     "0.949155"
#                 ],
#                 [
#                     17,
#                     18,
#                     "0.949155"
#                 ],
#                 [
#                     16,
#                     18,
#                     "0.5065808"
#                 ],
#                 [
#                     16,
#                     18,
#                     "0.5065808"
#                 ],
#                 [
#                     17,
#                     18,
#                     "0.949155"
#                 ],
#                 [
#                     17,
#                     18,
#                     "0.949155"
#                 ]
#             ],
#             "label": [
#                 "value",
#                 "0.93808955"
#             ],
#             "words": [
#                 {
#                     "text": "(336)",
#                     "box": [
#                         504,
#                         376,
#                         535,
#                         393
#                     ]
#                 },
#                 {
#                     "text": "335-",
#                     "box": [
#                         536,
#                         378,
#                         563,
#                         392
#                     ]
#                 },
#                 {
#                     "text": "7363",
#                     "box": [
#                         563,
#                         376,
#                         592,
#                         390
#                     ]
#                 }
#             ],
#             "id": 18
#         },
#         {
#             "text": "NUMBER OF PAGES INCLUDING COVER SHEET:",
#             "box": [
#                 102,
#                 439,
#                 421,
#                 457
#             ],
#             "linking": [
#                 [
#                     19,
#                     3,
#                     "0.87029165"
#                 ],
#                 [
#                     19,
#                     3,
#                     "0.87029165"
#                 ],
#                 [
#                     19,
#                     3,
#                     "0.87029165"
#                 ],
#                 [
#                     19,
#                     3,
#                     "0.87029165"
#                 ]
#             ],
#             "label": [
#                 "key",
#                 "0.9089458"
#             ],
#             "words": [
#                 {
#                     "text": "NUMBER",
#                     "box": [
#                         102,
#                         439,
#                         168,
#                         457
#                     ]
#                 },
#                 {
#                     "text": "OF",
#                     "box": [
#                         168,
#                         439,
#                         188,
#                         456
#                     ]
#                 },
#                 {
#                     "text": "PAGES",
#                     "box": [
#                         189,
#                         440,
#                         234,
#                         457
#                     ]
#                 },
#                 {
#                     "text": "INCLUDING",
#                     "box": [
#                         237,
#                         439,
#                         315,
#                         456
#                     ]
#                 },
#                 {
#                     "text": "COVER",
#                     "box": [
#                         318,
#                         439,
#                         368,
#                         454
#                     ]
#                 },
#                 {
#                     "text": "SHEET:",
#                     "box": [
#                         369,
#                         439,
#                         421,
#                         456
#                     ]
#                 }
#             ],
#             "id": 19
#         },
#         {
#             "text": "June Flynn for Eric Brown/ (614) 466- 8980",
#             "box": [
#                 304,
#                 471,
#                 537,
#                 487
#             ],
#             "linking": [
#                 [
#                     21,
#                     20,
#                     "0.84368247"
#                 ],
#                 [
#                     21,
#                     20,
#                     "0.84368247"
#                 ],
#                 [
#                     21,
#                     20,
#                     "0.84368247"
#                 ],
#                 [
#                     21,
#                     20,
#                     "0.84368247"
#                 ]
#             ],
#             "label": [
#                 "value",
#                 "0.91352534"
#             ],
#             "words": [
#                 {
#                     "text": "June",
#                     "box": [
#                         304,
#                         473,
#                         329,
#                         486
#                     ]
#                 },
#                 {
#                     "text": "Flynn",
#                     "box": [
#                         332,
#                         471,
#                         364,
#                         485
#                     ]
#                 },
#                 {
#                     "text": "for",
#                     "box": [
#                         367,
#                         473,
#                         382,
#                         486
#                     ]
#                 },
#                 {
#                     "text": "Eric",
#                     "box": [
#                         385,
#                         471,
#                         407,
#                         485
#                     ]
#                 },
#                 {
#                     "text": "Brown/",
#                     "box": [
#                         411,
#                         472,
#                         452,
#                         486
#                     ]
#                 },
#                 {
#                     "text": "(614)",
#                     "box": [
#                         450,
#                         472,
#                         481,
#                         487
#                     ]
#                 },
#                 {
#                     "text": "466-",
#                     "box": [
#                         482,
#                         472,
#                         504,
#                         486
#                     ]
#                 },
#                 {
#                     "text": "8980",
#                     "box": [
#                         506,
#                         472,
#                         537,
#                         487
#                     ]
#                 }
#             ],
#             "id": 20
#         },
#         {
#             "text": "SENDER /PHONE NUMBER:",
#             "box": [
#                 98,
#                 471,
#                 280,
#                 488
#             ],
#             "linking": [
#                 [
#                     21,
#                     20,
#                     "0.84368247"
#                 ],
#                 [
#                     21,
#                     20,
#                     "0.84368247"
#                 ],
#                 [
#                     21,
#                     20,
#                     "0.84368247"
#                 ],
#                 [
#                     21,
#                     20,
#                     "0.84368247"
#                 ]
#             ],
#             "label": [
#                 "key",
#                 "0.97773725"
#             ],
#             "words": [
#                 {
#                     "text": "SENDER",
#                     "box": [
#                         98,
#                         471,
#                         158,
#                         486
#                     ]
#                 },
#                 {
#                     "text": "/PHONE",
#                     "box": [
#                         159,
#                         472,
#                         212,
#                         486
#                     ]
#                 },
#                 {
#                     "text": "NUMBER:",
#                     "box": [
#                         214,
#                         471,
#                         280,
#                         488
#                     ]
#                 }
#             ],
#             "id": 21
#         },
#         {
#             "text": "SPECIAL INSTRUCTIONS:",
#             "box": [
#                 103,
#                 503,
#                 274,
#                 520
#             ],
#             "linking": [],
#             "label": [
#                 "other",
#                 "0.64342785"
#             ],
#             "words": [
#                 {
#                     "text": "SPECIAL",
#                     "box": [
#                         103,
#                         503,
#                         163,
#                         520
#                     ]
#                 },
#                 {
#                     "text": "INSTRUCTIONS:",
#                     "box": [
#                         165,
#                         503,
#                         274,
#                         520
#                     ]
#                 }
#             ],
#             "id": 22
#         },
#         {
#             "text": "IF YOU DO NOT RECEIVE ANY OF THE PAGES PROPERLY, PLEASE CONTACT SENDER AS SOON AS POSSIBLE",
#             "box": [
#                 175,
#                 599,
#                 556,
#                 646
#             ],
#             "linking": [],
#             "label": [
#                 "other",
#                 "0.769386"
#             ],
#             "words": [
#                 {
#                     "text": "IF",
#                     "box": [
#                         175,
#                         601,
#                         190,
#                         614
#                     ]
#                 },
#                 {
#                     "text": "YOU",
#                     "box": [
#                         191,
#                         601,
#                         222,
#                         615
#                     ]
#                 },
#                 {
#                     "text": "DO",
#                     "box": [
#                         225,
#                         601,
#                         245,
#                         614
#                     ]
#                 },
#                 {
#                     "text": "NOT",
#                     "box": [
#                         249,
#                         599,
#                         277,
#                         613
#                     ]
#                 },
#                 {
#                     "text": "RECEIVE",
#                     "box": [
#                         281,
#                         601,
#                         341,
#                         615
#                     ]
#                 },
#                 {
#                     "text": "ANY",
#                     "box": [
#                         344,
#                         601,
#                         373,
#                         612
#                     ]
#                 },
#                 {
#                     "text": "OF",
#                     "box": [
#                         376,
#                         599,
#                         394,
#                         612
#                     ]
#                 },
#                 {
#                     "text": "THE",
#                     "box": [
#                         397,
#                         599,
#                         426,
#                         613
#                     ]
#                 },
#                 {
#                     "text": "PAGES",
#                     "box": [
#                         427,
#                         599,
#                         473,
#                         614
#                     ]
#                 },
#                 {
#                     "text": "PROPERLY,",
#                     "box": [
#                         476,
#                         601,
#                         556,
#                         615
#                     ]
#                 },
#                 {
#                     "text": "PLEASE",
#                     "box": [
#                         274,
#                         616,
#                         330,
#                         630
#                     ]
#                 },
#                 {
#                     "text": "CONTACT",
#                     "box": [
#                         331,
#                         616,
#                         397,
#                         630
#                     ]
#                 },
#                 {
#                     "text": "SENDER",
#                     "box": [
#                         399,
#                         615,
#                         453,
#                         632
#                     ]
#                 },
#                 {
#                     "text": "AS",
#                     "box": [
#                         291,
#                         631,
#                         309,
#                         644
#                     ]
#                 },
#                 {
#                     "text": "SOON",
#                     "box": [
#                         311,
#                         631,
#                         349,
#                         645
#                     ]
#                 },
#                 {
#                     "text": "AS",
#                     "box": [
#                         352,
#                         633,
#                         370,
#                         646
#                     ]
#                 },
#                 {
#                     "text": "POSSIBLE",
#                     "box": [
#                         373,
#                         631,
#                         439,
#                         646
#                     ]
#                 }
#             ],
#             "id": 23
#         },
#         {
#             "text": "THIS MESSAGE IS INTENDED ONLY FOR THE USE OF THE INDIVIDUAL OR ENTITY TO WHOM IT IS ADDRESSED AND MAY CONTAIN INFORMATION THAT IS PRIVILEGED. CONFIDENTIAL, AND EXEMPT FROM DISCLOSURE UNDER APPLICABLE LAW. If the reader of this message is not the intended recipient of the employee or agent responsible for delivering the message to the intended recipient, you are hereby notified that any dissemination, distribution, copying, or conveying of this communication in any manner is strictly prohibited. If you have received this comunication in error, please notify us immediately by telephone and return the original message to us at the address below via the U. S. Postal Service. Thank you for your cooperation.",
#             "box": [
#                 162,
#                 691,
#                 626,
#                 813
#             ],
#             "linking": [],
#             "label": [
#                 "other",
#                 "0.846746"
#             ],
#             "words": [
#                 {
#                     "text": "THIS",
#                     "box": [
#                         163,
#                         691,
#                         190,
#                         704
#                     ]
#                 },
#                 {
#                     "text": "MESSAGE",
#                     "box": [
#                         193,
#                         691,
#                         245,
#                         705
#                     ]
#                 },
#                 {
#                     "text": "IS",
#                     "box": [
#                         249,
#                         693,
#                         260,
#                         704
#                     ]
#                 },
#                 {
#                     "text": "INTENDED",
#                     "box": [
#                         263,
#                         694,
#                         322,
#                         705
#                     ]
#                 },
#                 {
#                     "text": "ONLY",
#                     "box": [
#                         323,
#                         691,
#                         354,
#                         704
#                     ]
#                 },
#                 {
#                     "text": "FOR",
#                     "box": [
#                         356,
#                         693,
#                         378,
#                         706
#                     ]
#                 },
#                 {
#                     "text": "THE",
#                     "box": [
#                         381,
#                         693,
#                         405,
#                         704
#                     ]
#                 },
#                 {
#                     "text": "USE",
#                     "box": [
#                         408,
#                         693,
#                         428,
#                         704
#                     ]
#                 },
#                 {
#                     "text": "OF",
#                     "box": [
#                         432,
#                         693,
#                         447,
#                         704
#                     ]
#                 },
#                 {
#                     "text": "THE",
#                     "box": [
#                         450,
#                         693,
#                         472,
#                         704
#                     ]
#                 },
#                 {
#                     "text": "INDIVIDUAL",
#                     "box": [
#                         473,
#                         691,
#                         540,
#                         705
#                     ]
#                 },
#                 {
#                     "text": "OR",
#                     "box": [
#                         546,
#                         693,
#                         561,
#                         706
#                     ]
#                 },
#                 {
#                     "text": "ENTITY",
#                     "box": [
#                         564,
#                         693,
#                         605,
#                         704
#                     ]
#                 },
#                 {
#                     "text": "TO",
#                     "box": [
#                         609,
#                         694,
#                         624,
#                         704
#                     ]
#                 },
#                 {
#                     "text": "WHOM",
#                     "box": [
#                         163,
#                         705,
#                         201,
#                         716
#                     ]
#                 },
#                 {
#                     "text": "IT",
#                     "box": [
#                         204,
#                         707,
#                         218,
#                         717
#                     ]
#                 },
#                 {
#                     "text": "IS",
#                     "box": [
#                         222,
#                         707,
#                         235,
#                         718
#                     ]
#                 },
#                 {
#                     "text": "ADDRESSED",
#                     "box": [
#                         237,
#                         707,
#                         303,
#                         718
#                     ]
#                 },
#                 {
#                     "text": "AND",
#                     "box": [
#                         307,
#                         707,
#                         334,
#                         717
#                     ]
#                 },
#                 {
#                     "text": "MAY",
#                     "box": [
#                         337,
#                         707,
#                         364,
#                         718
#                     ]
#                 },
#                 {
#                     "text": "CONTAIN",
#                     "box": [
#                         369,
#                         707,
#                         419,
#                         718
#                     ]
#                 },
#                 {
#                     "text": "INFORMATION",
#                     "box": [
#                         422,
#                         705,
#                         500,
#                         719
#                     ]
#                 },
#                 {
#                     "text": "THAT",
#                     "box": [
#                         506,
#                         705,
#                         537,
#                         718
#                     ]
#                 },
#                 {
#                     "text": "IS",
#                     "box": [
#                         541,
#                         707,
#                         551,
#                         718
#                     ]
#                 },
#                 {
#                     "text": "PRIVILEGED.",
#                     "box": [
#                         553,
#                         707,
#                         623,
#                         720
#                     ]
#                 },
#                 {
#                     "text": "CONFIDENTIAL,",
#                     "box": [
#                         162,
#                         718,
#                         250,
#                         732
#                     ]
#                 },
#                 {
#                     "text": "AND",
#                     "box": [
#                         254,
#                         721,
#                         281,
#                         732
#                     ]
#                 },
#                 {
#                     "text": "EXEMPT",
#                     "box": [
#                         284,
#                         721,
#                         330,
#                         732
#                     ]
#                 },
#                 {
#                     "text": "FROM",
#                     "box": [
#                         332,
#                         721,
#                         366,
#                         731
#                     ]
#                 },
#                 {
#                     "text": "DISCLOSURE",
#                     "box": [
#                         369,
#                         721,
#                         439,
#                         732
#                     ]
#                 },
#                 {
#                     "text": "UNDER",
#                     "box": [
#                         441,
#                         719,
#                         480,
#                         730
#                     ]
#                 },
#                 {
#                     "text": "APPLICABLE",
#                     "box": [
#                         483,
#                         721,
#                         554,
#                         732
#                     ]
#                 },
#                 {
#                     "text": "LAW.",
#                     "box": [
#                         557,
#                         721,
#                         586,
#                         732
#                     ]
#                 },
#                 {
#                     "text": "If",
#                     "box": [
#                         594,
#                         722,
#                         607,
#                         732
#                     ]
#                 },
#                 {
#                     "text": "the",
#                     "box": [
# ...
#                     "box": [
#                         381,
#                         774,
#                         408,
#                         785
#                     ]
#                 },
#                 {
#                     "text": "us",
#                     "box": [
#                         413,
#                         777,
#                         423,
#                         785
#                     ]
#                 },
#                 {
#                     "text": "immediately",
#                     "box": [
#                         429,
#                         774,
#                         485,
#                         785
#                     ]
#                 },
#                 {
#                     "text": "by",
#                     "box": [
#                         487,
#                         774,
#                         500,
#                         785
#                     ]
#                 },
#                 {
#                     "text": "telephone",
#                     "box": [
#                         506,
#                         774,
#                         551,
#                         787
#                     ]
#                 },
#                 {
#                     "text": "and",
#                     "box": [
#                         553,
#                         775,
#                         573,
#                         785
#                     ]
#                 },
#                 {
#                     "text": "return",
#                     "box": [
#                         577,
#                         775,
#                         605,
#                         785
#                     ]
#                 },
#                 {
#                     "text": "the",
#                     "box": [
#                         608,
#                         774,
#                         623,
#                         784
#                     ]
#                 },
#                 {
#                     "text": "original",
#                     "box": [
#                         162,
#                         788,
#                         201,
#                         799
#                     ]
#                 },
#                 {
#                     "text": "message",
#                     "box": [
#                         204,
#                         786,
#                         243,
#                         799
#                     ]
#                 },
#                 {
#                     "text": "to",
#                     "box": [
#                         247,
#                         788,
#                         258,
#                         798
#                     ]
#                 },
#                 {
#                     "text": "us",
#                     "box": [
#                         263,
#                         789,
#                         274,
#                         797
#                     ]
#                 },
#                 {
#                     "text": "at",
#                     "box": [
#                         279,
#                         788,
#                         287,
#                         798
#                     ]
#                 },
#                 {
#                     "text": "the",
#                     "box": [
#                         291,
#                         788,
#                         306,
#                         798
#                     ]
#                 },
#                 {
#                     "text": "address",
#                     "box": [
#                         311,
#                         788,
#                         346,
#                         799
#                     ]
#                 },
#                 {
#                     "text": "below",
#                     "box": [
#                         349,
#                         788,
#                         378,
#                         799
#                     ]
#                 },
#                 {
#                     "text": "via",
#                     "box": [
#                         381,
#                         788,
#                         396,
#                         798
#                     ]
#                 },
#                 {
#                     "text": "the",
#                     "box": [
#                         401,
#                         788,
#                         415,
#                         798
#                     ]
#                 },
#                 {
#                     "text": "U.",
#                     "box": [
#                         419,
#                         786,
#                         430,
#                         797
#                     ]
#                 },
#                 {
#                     "text": "S.",
#                     "box": [
#                         432,
#                         788,
#                         442,
#                         798
#                     ]
#                 },
#                 {
#                     "text": "Postal",
#                     "box": [
#                         446,
#                         788,
#                         475,
#                         799
#                     ]
#                 },
#                 {
#                     "text": "Service.",
#                     "box": [
#                         478,
#                         788,
#                         516,
#                         798
#                     ]
#                 },
#                 {
#                     "text": "Thank",
#                     "box": [
#                         527,
#                         788,
#                         558,
#                         799
#                     ]
#                 },
#                 {
#                     "text": "you",
#                     "box": [
#                         560,
#                         789,
#                         580,
#                         800
#                     ]
#                 },
#                 {
#                     "text": "for",
#                     "box": [
#                         584,
#                         788,
#                         598,
#                         799
#                     ]
#                 },
#                 {
#                     "text": "your",
#                     "box": [
#                         602,
#                         789,
#                         624,
#                         800
#                     ]
#                 },
#                 {
#                     "text": "cooperation.",
#                     "box": [
#                         163,
#                         802,
#                         219,
#                         813
#                     ]
#                 }
#             ],
#             "id": 24
#         },
#         {
#             "text": "State Office Tower / 30 East Broad Street/ Columbus, Ohio 43215 -3428 www ag state oh us An Equal Opportunity Employer",
#             "box": [
#                 182,
#                 887,
#                 539,
#                 928
#             ],
#             "linking": [
#                 [
#                     26,
#                     25,
#                     "0.8808932"
#                 ],
#                 [
#                     26,
#                     25,
#                     "0.8808932"
#                 ],
#                 [
#                     26,
#                     25,
#                     "0.8808932"
#                 ],
#                 [
#                     26,
#                     25,
#                     "0.8808932"
#                 ]
#             ],
#             "label": [
#                 "value",
#                 "0.74662644"
#             ],
#             "words": [
#                 {
#                     "text": "State",
#                     "box": [
#                         182,
#                         887,
#                         209,
#                         902
#                     ]
#                 },
#                 {
#                     "text": "Office",
#                     "box": [
#                         211,
#                         890,
#                         240,
#                         901
#                     ]
#                 },
#                 {
#                     "text": "Tower",
#                     "box": [
#                         243,
#                         888,
#                         272,
#                         902
#                     ]
#                 },
#                 {
#                     "text": "/",
#                     "box": [
#                         275,
#                         888,
#                         281,
#                         899
#                     ]
#                 },
#                 {
#                     "text": "30",
#                     "box": [
#                         282,
#                         888,
#                         293,
#                         901
#                     ]
#                 },
#                 {
#                     "text": "East",
#                     "box": [
#                         296,
#                         888,
#                         318,
#                         899
#                     ]
#                 },
#                 {
#                     "text": "Broad",
#                     "box": [
#                         321,
#                         888,
#                         352,
#                         901
#                     ]
#                 },
#                 {
#                     "text": "Street/",
#                     "box": [
#                         355,
#                         888,
#                         391,
#                         899
#                     ]
#                 },
#                 {
#                     "text": "Columbus,",
#                     "box": [
#                         392,
#                         888,
#                         444,
#                         901
#                     ]
#                 },
#                 {
#                     "text": "Ohio",
#                     "box": [
#                         447,
#                         888,
#                         471,
#                         899
#                     ]
#                 },
#                 {
#                     "text": "43215",
#                     "box": [
#                         476,
#                         887,
#                         507,
#                         900
#                     ]
#                 },
#                 {
#                     "text": "-3428",
#                     "box": [
#                         508,
#                         887,
#                         539,
#                         901
#                     ]
#                 },
#                 {
#                     "text": "www",
#                     "box": [
#                         310,
#                         902,
#                         338,
#                         913
#                     ]
#                 },
#                 {
#                     "text": "ag",
#                     "box": [
#                         339,
#                         902,
#                         352,
#                         915
#                     ]
#                 },
#                 {
#                     "text": "state",
#                     "box": [
#                         352,
#                         902,
#                         377,
#                         913
#                     ]
#                 },
#                 {
#                     "text": "oh",
#                     "box": [
#                         378,
#                         902,
#                         392,
#                         913
#                     ]
#                 },
#                 {
#                     "text": "us",
#                     "box": [
#                         394,
#                         904,
#                         408,
#                         912
#                     ]
#                 },
#                 {
#                     "text": "An",
#                     "box": [
#                         292,
#                         915,
#                         305,
#                         926
#                     ]
#                 },
#                 {
#                     "text": "Equal",
#                     "box": [
#                         307,
#                         913,
#                         332,
#                         927
#                     ]
#                 },
#                 {
#                     "text": "Opportunity",
#                     "box": [
#                         335,
#                         915,
#                         387,
#                         928
#                     ]
#                 },
#                 {
#                     "text": "Employer",
#                     "box": [
#                         387,
#                         916,
#                         429,
#                         927
#                     ]
#                 }
#             ],
#             "id": 25
#         },
#         {
#             "text": "Primed an ",
#             "box": [
#                 292,
#                 941,
#                 426,
#                 954
#             ],
#             "linking": [
#                 [
#                     26,
#                     25,
#                     "0.8808932"
#                 ],
#                 [
#                     26,
#                     25,
#                     "0.8808932"
#                 ],
#                 [
#                     26,
#                     25,
#                     "0.8808932"
#                 ],
#                 [
#                     26,
#                     25,
#                     "0.8808932"
#                 ]
#             ],
#             "label": [
#                 "key",
#                 "0.80711704"
#             ],
#             "words": [
#                 {
#                     "text": "",
#                     "box": [
#                         292,
#                         941,
#                         306,
#                         954
#                     ]
#                 },
#                 {
#                     "text": "Primed",
#                     "box": [
#                         306,
#                         943,
#                         341,
#                         951
#                     ]
#                 },
#                 {
#                     "text": "an",
#                     "box": [
#                         341,
#                         944,
#                         355,
#                         951
#                     ]
#                 },
#                 {
#                     "text": "",
#                     "box": [
#                         355,
#                         943,
#                         398,
#                         951
#                     ]
#                 },
#                 {
#                     "text": "",
#                     "box": [
#                         399,
#                         943,
#                         426,
#                         951
#                     ]
#                 }
#             ],
#             "id": 26
#         },
#         {
#             "text": "12 /10 /98",
#             "box": [
#                 184,
#                 405,
#                 233,
#                 423
#             ],
#             "linking": [
#                 [
#                     2,
#                     27,
#                     "0.9670255"
#                 ],
#                 [
#                     2,
#                     27,
#                     "0.9670255"
#                 ],
#                 [
#                     2,
#                     27,
#                     "0.9670255"
#                 ],
#                 [
#                     2,
#                     27,
#                     "0.9670255"
#                 ]
#             ],
#             "label": [
#                 "value",
#                 "0.96134686"
#             ],
#             "words": [
#                 {
#                     "text": "12",
#                     "box": [
#                         184,
#                         406,
#                         198,
#                         420
#                     ]
#                 },
#                 {
#                     "text": "/10",
#                     "box": [
#                         198,
#                         405,
#                         216,
#                         423
#                     ]
#                 },
#                 {
#                     "text": "/98",
#                     "box": [
#                         215,
#                         406,
#                         233,
#                         423
#                     ]
#                 }
#             ],
#             "id": 27
#         }
#     ]
# }
